# %% [markdown]
# ## ServiceTitan Internship Round 1 Task

# %%
import pickle
import pandas as pd
from datetime import datetime

# %% [markdown]
# **As seen below, the original data has several inconsistencies:**

# %% [markdown]
# * There are Invoice IDs in the data that have letters at the end.
# * There are examples in 'quantity' that have word numbers instead of integers in the values, e.g. 'ten' instead of 10.
# * In 'type' there is a letter instead of numbers.
# * There are two out-of-range date examples which show February 30th.

# %%
with open("data\invoices_new.pkl", 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# [{'id': '365371O',
#   'created_on': '2019-05-27',
#   'items': [{'item': {'id': 142446,
#      'name': 'ii_142446',
#      'unit_price': 182,
#      'type': 1},
#     'quantity': 6},
#    {'item': {'id': 154019, 'name': 'ii_154019', 'unit_price': 176, 'type': 1},
#     'quantity': 1}]},
#  {'id': 389528,
#   'created_on': '2019-03-19',
#   'items': [{'item': {'id': 172535,
#      'name': 'ii_172535',
#      'unit_price': 105,
#      'type': 0},
#     'quantity': 4},
#    {'item': {'id': 175208, 'name': 'ii_175208', 'unit_price': 109, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 139970, 'name': 'ii_139970', 'unit_price': 193, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 156273, 'name': 'ii_156273', 'unit_price': 129, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 178512, 'name': 'ii_178512', 'unit_price': 108, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 191045, 'name': 'ii_191045', 'unit_price': 195, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 189841, 'name': 'ii_189841', 'unit_price': 171, 'type': 1},
#     'quantity': 4}]},
#  {'id': 341762,
#   'created_on': '2019-06-19',
#   'items': [{'item': {'id': 143176,
#      'name': 'ii_143176',
#      'unit_price': 175,
#      'type': 2},
#     'quantity': 2},
#    {'item': {'id': 161765, 'name': 'ii_161765', 'unit_price': 170, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 167763, 'name': 'ii_167763', 'unit_price': 150, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 195203, 'name': 'ii_195203', 'unit_price': 194, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 188321, 'name': 'ii_188321', 'unit_price': 101, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 114990, 'name': 'ii_114990', 'unit_price': 132, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 126940, 'name': 'ii_126940', 'unit_price': 166, 'type': 0},
#     'quantity': 3}]},
#  {'id': 319405,
#   'created_on': '2019-03-27',
#   'items': [{'item': {'id': 141009,
#      'name': 'ii_141009',
#      'unit_price': 161,
#      'type': 0},
#     'quantity': 1},
#    {'item': {'id': 195216, 'name': 'ii_195216', 'unit_price': 140, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 108059, 'name': 'ii_108059', 'unit_price': 118, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 171459, 'name': 'ii_171459', 'unit_price': 187, 'type': 3},
#     'quantity': 1}]},
#  {'id': 343695,
#   'created_on': '2019-04-10',
#   'items': [{'item': {'id': 144025,
#      'name': 'ii_144025',
#      'unit_price': 101,
#      'type': 3},
#     'quantity': 'ten'},
#    {'item': {'id': 147038, 'name': 'ii_147038', 'unit_price': 177, 'type': 0},
#     'quantity': 1}]},
#  {'id': 358095,
#   'created_on': '2019-03-19',
#   'items': [{'item': {'id': 147214,
#      'name': 'ii_147214',
#      'unit_price': 117,
#      'type': 0},
#     'quantity': 4},
#    {'item': {'id': 152191, 'name': 'ii_152191', 'unit_price': 135, 'type': 1},
#     'quantity': 6}]},
#  {'id': 381281,
#   'created_on': '2019-05-16',
#   'items': [{'item': {'id': 191864,
#      'name': 'ii_191864',
#      'unit_price': 176,
#      'type': 2},
#     'quantity': 2},
#    {'item': {'id': 110832, 'name': 'ii_110832', 'unit_price': 124, 'type': 3},
#     'quantity': 4}]},
#  {'id': 352391,
#   'created_on': '2019-01-18',
#   'items': [{'item': {'id': 178909,
#      'name': 'ii_178909',
#      'unit_price': 161,
#      'type': 3},
#     'quantity': 1},
#    {'item': {'id': 104981, 'name': 'ii_104981', 'unit_price': 141, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 167699, 'name': 'ii_167699', 'unit_price': 144, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 193687, 'name': 'ii_193687', 'unit_price': 166, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 138301, 'name': 'ii_138301', 'unit_price': 128, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 179050, 'name': 'ii_179050', 'unit_price': 162, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 198345, 'name': 'ii_198345', 'unit_price': 125, 'type': 2},
#     'quantity': 2}]},
#  {'id': '374089O',
#   'created_on': '2019-09-30',
#   'items': [{'item': {'id': 160942,
#      'name': 'ii_160942',
#      'unit_price': 162,
#      'type': 2},
#     'quantity': 4},
#    {'item': {'id': 156315, 'name': 'ii_156315', 'unit_price': 151, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 128859, 'name': 'ii_128859', 'unit_price': 117, 'type': 1},
#     'quantity': 1},
#    {'item': {'id': 152319, 'name': 'ii_152319', 'unit_price': 161, 'type': 3},
#     'quantity': 2}]},
#  {'id': 331193,
#   'created_on': '2019-04-12',
#   'items': [{'item': {'id': 195938,
#      'name': 'ii_195938',
#      'unit_price': 129,
#      'type': 'O'},
#     'quantity': 2},
#    {'item': {'id': 160255, 'name': 'ii_160255', 'unit_price': 169, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 198688, 'name': 'ii_198688', 'unit_price': 102, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 101279, 'name': 'ii_101279', 'unit_price': 164, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 105136, 'name': 'ii_105136', 'unit_price': 193, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 167356, 'name': 'ii_167356', 'unit_price': 118, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 130940, 'name': 'ii_130940', 'unit_price': 145, 'type': 2},
#     'quantity': 2}]},
#  {'id': 347510,
#   'created_on': '2019-02-10',
#   'items': [{'item': {'id': 142237,
#      'name': 'ii_142237',
#      'unit_price': 167,
#      'type': 1},
#     'quantity': 8},
#    {'item': {'id': 106048, 'name': 'ii_106048', 'unit_price': 188, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 166330, 'name': 'ii_166330', 'unit_price': 116, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 197845, 'name': 'ii_197845', 'unit_price': 173, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 133899, 'name': 'ii_133899', 'unit_price': 144, 'type': 3},
#     'quantity': 7}]},
#  {'id': 307175,
#   'created_on': '2019-05-19',
#   'items': [{'item': {'id': 134663,
#      'name': 'ii_134663',
#      'unit_price': 175,
#      'type': 0},
#     'quantity': 8},
#    {'item': {'id': 136924, 'name': 'ii_136924', 'unit_price': 183, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 122138, 'name': 'ii_122138', 'unit_price': 195, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 133742, 'name': 'ii_133742', 'unit_price': 115, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 185633, 'name': 'ii_185633', 'unit_price': 119, 'type': 0},
#     'quantity': 2}]},
#  {'id': 369378,
#   'created_on': '2019-07-15',
#   'items': [{'item': {'id': 137032,
#      'name': 'ii_137032',
#      'unit_price': 116,
#      'type': 'O'},
#     'quantity': 5},
#    {'item': {'id': 126483, 'name': 'ii_126483', 'unit_price': 165, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 108758, 'name': 'ii_108758', 'unit_price': 177, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 183393, 'name': 'ii_183393', 'unit_price': 194, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 190308, 'name': 'ii_190308', 'unit_price': 124, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 177376, 'name': 'ii_177376', 'unit_price': 127, 'type': 3},
#     'quantity': 7}]},
#  {'id': 377307,
#   'created_on': '2019-04-12',
#   'items': [{'item': {'id': 174987,
#      'name': 'ii_174987',
#      'unit_price': 127,
#      'type': 1},
#     'quantity': 4},
#    {'item': {'id': 151916, 'name': 'ii_151916', 'unit_price': 117, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 194584, 'name': 'ii_194584', 'unit_price': 146, 'type': 0},
#     'quantity': 4},
#    {'item': {'id': 190386, 'name': 'ii_190386', 'unit_price': 156, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 151535, 'name': 'ii_151535', 'unit_price': 139, 'type': 1},
#     'quantity': 4}]},
#  {'id': 367288,
#   'created_on': '2019-06-29',
#   'items': [{'item': {'id': 117929,
#      'name': 'ii_117929',
#      'unit_price': 155,
#      'type': 3},
#     'quantity': 4},
#    {'item': {'id': 182802, 'name': 'ii_182802', 'unit_price': 155, 'type': 3},
#     'quantity': 3},
#    {'item': {'id': 104800, 'name': 'ii_104800', 'unit_price': 103, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 146906, 'name': 'ii_146906', 'unit_price': 132, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 178253, 'name': 'ii_178253', 'unit_price': 104, 'type': 1},
#     'quantity': 2}]},
#  {'id': 337140,
#   'created_on': '2019-06-23',
#   'items': [{'item': {'id': 131446,
#      'name': 'ii_131446',
#      'unit_price': 196,
#      'type': 2},
#     'quantity': 1},
#    {'item': {'id': 168508, 'name': 'ii_168508', 'unit_price': 109, 'type': 0},
#     'quantity': 4},
#    {'item': {'id': 171389, 'name': 'ii_171389', 'unit_price': 183, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 117794, 'name': 'ii_117794', 'unit_price': 155, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 184268, 'name': 'ii_184268', 'unit_price': 147, 'type': 3},
#     'quantity': 1}]},
#  {'id': 315960,
#   'created_on': '2019-09-27',
#   'items': [{'item': {'id': 117240,
#      'name': 'ii_117240',
#      'unit_price': 139,
#      'type': 3},
#     'quantity': 3},
#    {'item': {'id': 104513, 'name': 'ii_104513', 'unit_price': 165, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 172757, 'name': 'ii_172757', 'unit_price': 155, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 103202, 'name': 'ii_103202', 'unit_price': 113, 'type': 1},
#     'quantity': 6},
#    {'item': {'id': 100883, 'name': 'ii_100883', 'unit_price': 187, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 194744, 'name': 'ii_194744', 'unit_price': 131, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 128573, 'name': 'ii_128573', 'unit_price': 119, 'type': 1},
#     'quantity': 4}]},
#  {'id': 340601,
#   'created_on': '2019-08-16',
#   'items': [{'item': {'id': 144257,
#      'name': 'ii_144257',
#      'unit_price': 148,
#      'type': 0},
#     'quantity': 7},
#    {'item': {'id': 116446, 'name': 'ii_116446', 'unit_price': 129, 'type': 2},
#     'quantity': 7},
#    {'item': {'id': 126267, 'name': 'ii_126267', 'unit_price': 171, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 145047, 'name': 'ii_145047', 'unit_price': 163, 'type': 0},
#     'quantity': 1}]},
#  {'id': '397723O',
#   'created_on': '2019-05-11',
#   'items': [{'item': {'id': 181613,
#      'name': 'ii_181613',
#      'unit_price': 161,
#      'type': 0},
#     'quantity': 3},
#    {'item': {'id': 117999, 'name': 'ii_117999', 'unit_price': 196, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 198198, 'name': 'ii_198198', 'unit_price': 122, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 121772, 'name': 'ii_121772', 'unit_price': 120, 'type': 0},
#     'quantity': 5}]},
#  {'id': 379687,
#   'created_on': '2019-05-24',
#   'items': [{'item': {'id': 139615,
#      'name': 'ii_139615',
#      'unit_price': 194,
#      'type': 0},
#     'quantity': 3},
#    {'item': {'id': 155726, 'name': 'ii_155726', 'unit_price': 149, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 188916, 'name': 'ii_188916', 'unit_price': 165, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 164157, 'name': 'ii_164157', 'unit_price': 195, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 135770, 'name': 'ii_135770', 'unit_price': 174, 'type': 3},
#     'quantity': 3},
#    {'item': {'id': 107730, 'name': 'ii_107730', 'unit_price': 177, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 139278, 'name': 'ii_139278', 'unit_price': 120, 'type': 0},
#     'quantity': 7}]},
#  {'id': 309022,
#   'created_on': '2019-04-18',
#   'items': [{'item': {'id': 161511,
#      'name': 'ii_161511',
#      'unit_price': 102,
#      'type': 1},
#     'quantity': 2},
#    {'item': {'id': 197972, 'name': 'ii_197972', 'unit_price': 145, 'type': 3},
#     'quantity': 3},
#    {'item': {'id': 123298, 'name': 'ii_123298', 'unit_price': 189, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 105792, 'name': 'ii_105792', 'unit_price': 106, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 109859, 'name': 'ii_109859', 'unit_price': 117, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 171220, 'name': 'ii_171220', 'unit_price': 136, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 131338, 'name': 'ii_131338', 'unit_price': 197, 'type': 1},
#     'quantity': 1}]},
#  {'id': '325156O',
#   'created_on': '2019-06-25',
#   'items': [{'item': {'id': 169797,
#      'name': 'ii_169797',
#      'unit_price': 116,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 132735, 'name': 'ii_132735', 'unit_price': 181, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 109190, 'name': 'ii_109190', 'unit_price': 189, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 150736, 'name': 'ii_150736', 'unit_price': 138, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 142199, 'name': 'ii_142199', 'unit_price': 130, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 197255, 'name': 'ii_197255', 'unit_price': 142, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 119673, 'name': 'ii_119673', 'unit_price': 130, 'type': 0},
#     'quantity': 2}]},
#  {'id': 316710,
#   'created_on': '2019-05-25',
#   'items': [{'item': {'id': 182123,
#      'name': 'ii_182123',
#      'unit_price': 137,
#      'type': 1},
#     'quantity': 4},
#    {'item': {'id': 135307, 'name': 'ii_135307', 'unit_price': 149, 'type': 3},
#     'quantity': 8}]},
#  {'id': 370388,
#   'created_on': '2019-09-12',
#   'items': [{'item': {'id': 183848,
#      'name': 'ii_183848',
#      'unit_price': 112,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 165619, 'name': 'ii_165619', 'unit_price': 142, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 181685, 'name': 'ii_181685', 'unit_price': 200, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 124709, 'name': 'ii_124709', 'unit_price': 115, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 129808, 'name': 'ii_129808', 'unit_price': 185, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 112870, 'name': 'ii_112870', 'unit_price': 102, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 102035, 'name': 'ii_102035', 'unit_price': 173, 'type': 2},
#     'quantity': 8}]},
#  {'id': 307923,
#   'created_on': '2019-04-20',
#   'items': [{'item': {'id': 118576,
#      'name': 'ii_118576',
#      'unit_price': 183,
#      'type': 3},
#     'quantity': 4},
#    {'item': {'id': 103717, 'name': 'ii_103717', 'unit_price': 100, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 127738, 'name': 'ii_127738', 'unit_price': 106, 'type': 0},
#     'quantity': 4}]},
#  {'id': '326649O',
#   'created_on': '2019-02-27',
#   'items': [{'item': {'id': 170022,
#      'name': 'ii_170022',
#      'unit_price': 190,
#      'type': 1},
#     'quantity': 7},
#    {'item': {'id': 177477, 'name': 'ii_177477', 'unit_price': 116, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 170207, 'name': 'ii_170207', 'unit_price': 191, 'type': 1},
#     'quantity': 8}]},
#  {'id': 369292,
#   'created_on': '2019-09-13',
#   'items': [{'item': {'id': 125771,
#      'name': 'ii_125771',
#      'unit_price': 194,
#      'type': 1},
#     'quantity': 7},
#    {'item': {'id': 107345, 'name': 'ii_107345', 'unit_price': 120, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 106241, 'name': 'ii_106241', 'unit_price': 183, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 191895, 'name': 'ii_191895', 'unit_price': 114, 'type': 0},
#     'quantity': 4}]},
#  {'id': 304245,
#   'created_on': '2019-03-17',
#   'items': [{'item': {'id': 121446,
#      'name': 'ii_121446',
#      'unit_price': 158,
#      'type': 2},
#     'quantity': 4},
#    {'item': {'id': 155308, 'name': 'ii_155308', 'unit_price': 161, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 143674, 'name': 'ii_143674', 'unit_price': 176, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 161145, 'name': 'ii_161145', 'unit_price': 191, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 155679, 'name': 'ii_155679', 'unit_price': 194, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 135235, 'name': 'ii_135235', 'unit_price': 151, 'type': 2},
#     'quantity': 6}]},
#  {'id': 392733,
#   'created_on': '2019-07-12',
#   'items': [{'item': {'id': 149945,
#      'name': 'ii_149945',
#      'unit_price': 116,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 122938, 'name': 'ii_122938', 'unit_price': 120, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 196413, 'name': 'ii_196413', 'unit_price': 125, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 142303, 'name': 'ii_142303', 'unit_price': 126, 'type': 3},
#     'quantity': 3}]},
#  {'id': 335732,
#   'created_on': '2019-08-10',
#   'items': [{'item': {'id': 178111,
#      'name': 'ii_178111',
#      'unit_price': 187,
#      'type': 3},
#     'quantity': 6},
#    {'item': {'id': 134919, 'name': 'ii_134919', 'unit_price': 158, 'type': 3},
#     'quantity': 3},
#    {'item': {'id': 198017, 'name': 'ii_198017', 'unit_price': 152, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 189409, 'name': 'ii_189409', 'unit_price': 194, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 159222, 'name': 'ii_159222', 'unit_price': 171, 'type': 2},
#     'quantity': 1}]},
#  {'id': 363284,
#   'created_on': '2019-09-21',
#   'items': [{'item': {'id': 107763,
#      'name': 'ii_107763',
#      'unit_price': 110,
#      'type': 3},
#     'quantity': 6},
#    {'item': {'id': 180493, 'name': 'ii_180493', 'unit_price': 144, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 154557, 'name': 'ii_154557', 'unit_price': 131, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 147178, 'name': 'ii_147178', 'unit_price': 165, 'type': 0},
#     'quantity': 5},
#    {'item': {'id': 171334, 'name': 'ii_171334', 'unit_price': 172, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 128292, 'name': 'ii_128292', 'unit_price': 134, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 170804, 'name': 'ii_170804', 'unit_price': 195, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 144611, 'name': 'ii_144611', 'unit_price': 172, 'type': 1},
#     'quantity': 5}]},
#  {'id': 373241,
#   'created_on': '2019-02-19',
#   'items': [{'item': {'id': 196536,
#      'name': 'ii_196536',
#      'unit_price': 196,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 161678, 'name': 'ii_161678', 'unit_price': 140, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 116519, 'name': 'ii_116519', 'unit_price': 161, 'type': 1},
#     'quantity': 1},
#    {'item': {'id': 118309, 'name': 'ii_118309', 'unit_price': 126, 'type': 0},
#     'quantity': 8}]},
#  {'id': 379961, 'created_on': '2019-05-12'},
#  {'id': '385290O',
#   'created_on': '2019-06-29',
#   'items': [{'item': {'id': 150069,
#      'name': 'ii_150069',
#      'unit_price': 114,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 168488, 'name': 'ii_168488', 'unit_price': 116, 'type': 1},
#     'quantity': 2}]},
#  {'id': 394428,
#   'created_on': '2019-09-26',
#   'items': [{'item': {'id': 141154,
#      'name': 'ii_141154',
#      'unit_price': 129,
#      'type': 1},
#     'quantity': 5},
#    {'item': {'id': 120256, 'name': 'ii_120256', 'unit_price': 100, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 192645, 'name': 'ii_192645', 'unit_price': 102, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 194735, 'name': 'ii_194735', 'unit_price': 100, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 141457, 'name': 'ii_141457', 'unit_price': 181, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 160040, 'name': 'ii_160040', 'unit_price': 137, 'type': 0},
#     'quantity': 7}]},
#  {'id': 326452,
#   'created_on': '2019-08-21',
#   'items': [{'item': {'id': 155752,
#      'name': 'ii_155752',
#      'unit_price': 102,
#      'type': 1},
#     'quantity': 4},
#    {'item': {'id': 157444, 'name': 'ii_157444', 'unit_price': 154, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 124339, 'name': 'ii_124339', 'unit_price': 200, 'type': 1},
#     'quantity': 4},
#    {'item': {'id': 154969, 'name': 'ii_154969', 'unit_price': 151, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 168281, 'name': 'ii_168281', 'unit_price': 144, 'type': 3},
#     'quantity': 6}]},
#  {'id': 342057,
#   'created_on': '2019-07-14',
#   'items': [{'item': {'id': 143077,
#      'name': 'ii_143077',
#      'unit_price': 103,
#      'type': 0},
#     'quantity': 4},
#    {'item': {'id': 119152, 'name': 'ii_119152', 'unit_price': 155, 'type': 2},
#     'quantity': 8}]},
#  {'id': 356817,
#   'created_on': '2019-05-14',
#   'items': [{'item': {'id': 182969,
#      'name': 'ii_182969',
#      'unit_price': 107,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 126581, 'name': 'ii_126581', 'unit_price': 115, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 156873, 'name': 'ii_156873', 'unit_price': 166, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 129822, 'name': 'ii_129822', 'unit_price': 117, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 192836, 'name': 'ii_192836', 'unit_price': 171, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 190522, 'name': 'ii_190522', 'unit_price': 156, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 189295, 'name': 'ii_189295', 'unit_price': 178, 'type': 2},
#     'quantity': 5}]},
#  {'id': '381476O',
#   'created_on': '2019-07-12',
#   'items': [{'item': {'id': 195222,
#      'name': 'ii_195222',
#      'unit_price': 186,
#      'type': 3},
#     'quantity': 8},
#    {'item': {'id': 121779, 'name': 'ii_121779', 'unit_price': 195, 'type': 2},
#     'quantity': 5}]},
#  {'id': 322229,
#   'created_on': '2019-07-27',
#   'items': [{'item': {'id': 113336,
#      'name': 'ii_113336',
#      'unit_price': 121,
#      'type': 0},
#     'quantity': 3},
#    {'item': {'id': 153568, 'name': 'ii_153568', 'unit_price': 127, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 101063, 'name': 'ii_101063', 'unit_price': 149, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 155936, 'name': 'ii_155936', 'unit_price': 171, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 178996, 'name': 'ii_178996', 'unit_price': 194, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 145514, 'name': 'ii_145514', 'unit_price': 191, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 130624, 'name': 'ii_130624', 'unit_price': 167, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 178642, 'name': 'ii_178642', 'unit_price': 126, 'type': 2},
#     'quantity': 8}]},
#  {'id': 377719,
#   'created_on': '2019-01-25',
#   'items': [{'item': {'id': 157233,
#      'name': 'ii_157233',
#      'unit_price': 150,
#      'type': 1},
#     'quantity': 1},
#    {'item': {'id': 172149, 'name': 'ii_172149', 'unit_price': 192, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 178297, 'name': 'ii_178297', 'unit_price': 124, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 129849, 'name': 'ii_129849', 'unit_price': 159, 'type': 1},
#     'quantity': 1}]},
#  {'id': 389694,
#   'created_on': '2019-04-15',
#   'items': [{'item': {'id': 124910,
#      'name': 'ii_124910',
#      'unit_price': 152,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 124712, 'name': 'ii_124712', 'unit_price': 113, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 141350, 'name': 'ii_141350', 'unit_price': 172, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 145685, 'name': 'ii_145685', 'unit_price': 173, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 156848, 'name': 'ii_156848', 'unit_price': 198, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 132887, 'name': 'ii_132887', 'unit_price': 157, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 175476, 'name': 'ii_175476', 'unit_price': 145, 'type': 1},
#     'quantity': 3}]},
#  {'id': 371205,
#   'created_on': '2019-09-16',
#   'items': [{'item': {'id': 134708,
#      'name': 'ii_134708',
#      'unit_price': 161,
#      'type': 0},
#     'quantity': 2},
#    {'item': {'id': 168830, 'name': 'ii_168830', 'unit_price': 133, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 191084, 'name': 'ii_191084', 'unit_price': 153, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 136658, 'name': 'ii_136658', 'unit_price': 166, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 140599, 'name': 'ii_140599', 'unit_price': 168, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 128266, 'name': 'ii_128266', 'unit_price': 125, 'type': 2},
#     'quantity': 5}]},
#  {'id': 373470,
#   'created_on': '2019-09-22',
#   'items': [{'item': {'id': 111542,
#      'name': 'ii_111542',
#      'unit_price': 131,
#      'type': 3},
#     'quantity': 1},
#    {'item': {'id': 132455, 'name': 'ii_132455', 'unit_price': 172, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 132910, 'name': 'ii_132910', 'unit_price': 169, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 116917, 'name': 'ii_116917', 'unit_price': 166, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 193726, 'name': 'ii_193726', 'unit_price': 180, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 193693, 'name': 'ii_193693', 'unit_price': 144, 'type': 0},
#     'quantity': 3}]},
#  {'id': 352442,
#   'created_on': '2019-02-25',
#   'items': [{'item': {'id': 146726,
#      'name': 'ii_146726',
#      'unit_price': 148,
#      'type': 3},
#     'quantity': 7},
#    {'item': {'id': 126440, 'name': 'ii_126440', 'unit_price': 166, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 107250, 'name': 'ii_107250', 'unit_price': 116, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 108496, 'name': 'ii_108496', 'unit_price': 128, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 195973, 'name': 'ii_195973', 'unit_price': 181, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 179715, 'name': 'ii_179715', 'unit_price': 136, 'type': 1},
#     'quantity': 2}]},
#  {'id': 331601,
#   'created_on': '2019-03-26',
#   'items': [{'item': {'id': 114112,
#      'name': 'ii_114112',
#      'unit_price': 189,
#      'type': 0},
#     'quantity': 7},
#    {'item': {'id': 139457, 'name': 'ii_139457', 'unit_price': 190, 'type': 0},
#     'quantity': 2}]},
#  {'id': 338547,
#   'created_on': '2019-03-13',
#   'items': [{'item': {'id': 138537,
#      'name': 'ii_138537',
#      'unit_price': 134,
#      'type': 1},
#     'quantity': 6},
#    {'item': {'id': 174862, 'name': 'ii_174862', 'unit_price': 171, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 117018, 'name': 'ii_117018', 'unit_price': 124, 'type': 2},
#     'quantity': 5}]},
#  {'id': 350506, 'created_on': '2019-01-24'},
#  {'id': 392657,
#   'created_on': '2019-04-25',
#   'items': [{'item': {'id': 121582,
#      'name': 'ii_121582',
#      'unit_price': 181,
#      'type': 'O'},
#     'quantity': 6},
#    {'item': {'id': 168169, 'name': 'ii_168169', 'unit_price': 180, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 168613, 'name': 'ii_168613', 'unit_price': 182, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 109352, 'name': 'ii_109352', 'unit_price': 197, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 180133, 'name': 'ii_180133', 'unit_price': 181, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 130960, 'name': 'ii_130960', 'unit_price': 195, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 189971, 'name': 'ii_189971', 'unit_price': 199, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 109781, 'name': 'ii_109781', 'unit_price': 177, 'type': 2},
#     'quantity': 2}]},
#  {'id': 377572,
#   'created_on': '2019-06-24',
#   'items': [{'item': {'id': 146917,
#      'name': 'ii_146917',
#      'unit_price': 146,
#      'type': 3},
#     'quantity': 5},
#    {'item': {'id': 164691, 'name': 'ii_164691', 'unit_price': 135, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 136284, 'name': 'ii_136284', 'unit_price': 109, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 139346, 'name': 'ii_139346', 'unit_price': 154, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 107683, 'name': 'ii_107683', 'unit_price': 195, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 171957, 'name': 'ii_171957', 'unit_price': 121, 'type': 1},
#     'quantity': 8}]},
#  {'id': 324751,
#   'created_on': '2019-02-27',
#   'items': [{'item': {'id': 165882,
#      'name': 'ii_165882',
#      'unit_price': 147,
#      'type': 0},
#     'quantity': 1},
#    {'item': {'id': 129989, 'name': 'ii_129989', 'unit_price': 117, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 157890, 'name': 'ii_157890', 'unit_price': 160, 'type': 0},
#     'quantity': 3}]},
#  {'id': 347243,
#   'created_on': '2019-05-16',
#   'items': [{'item': {'id': 199938,
#      'name': 'ii_199938',
#      'unit_price': 160,
#      'type': 3},
#     'quantity': 5},
#    {'item': {'id': 187864, 'name': 'ii_187864', 'unit_price': 195, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 180620, 'name': 'ii_180620', 'unit_price': 121, 'type': 1},
#     'quantity': 1},
#    {'item': {'id': 128879, 'name': 'ii_128879', 'unit_price': 196, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 115441, 'name': 'ii_115441', 'unit_price': 122, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 176261, 'name': 'ii_176261', 'unit_price': 196, 'type': 0},
#     'quantity': 5}]},
#  {'id': 344265,
#   'created_on': '2019-09-28',
#   'items': [{'item': {'id': 155135,
#      'name': 'ii_155135',
#      'unit_price': 109,
#      'type': 3},
#     'quantity': 4},
#    {'item': {'id': 114882, 'name': 'ii_114882', 'unit_price': 180, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 146936, 'name': 'ii_146936', 'unit_price': 128, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 110235, 'name': 'ii_110235', 'unit_price': 120, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 127274, 'name': 'ii_127274', 'unit_price': 107, 'type': 1},
#     'quantity': 6},
#    {'item': {'id': 110104, 'name': 'ii_110104', 'unit_price': 194, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 196026, 'name': 'ii_196026', 'unit_price': 187, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 131891, 'name': 'ii_131891', 'unit_price': 112, 'type': 3},
#     'quantity': 3}]},
#  {'id': 349879,
#   'created_on': '2019-01-11',
#   'items': [{'item': {'id': 170792,
#      'name': 'ii_170792',
#      'unit_price': 180,
#      'type': 1},
#     'quantity': 3},
#    {'item': {'id': 161820, 'name': 'ii_161820', 'unit_price': 186, 'type': 3},
#     'quantity': 3}]},
#  {'id': '335226O',
#   'created_on': '2019-05-24',
#   'items': [{'item': {'id': 100942,
#      'name': 'ii_100942',
#      'unit_price': 117,
#      'type': 0},
#     'quantity': 4},
#    {'item': {'id': 142902, 'name': 'ii_142902', 'unit_price': 194, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 165153, 'name': 'ii_165153', 'unit_price': 193, 'type': 1},
#     'quantity': 8}]},
#  {'id': 383681,
#   'created_on': '2019-07-21',
#   'items': [{'item': {'id': 178938,
#      'name': 'ii_178938',
#      'unit_price': 197,
#      'type': 3},
#     'quantity': 8},
#    {'item': {'id': 105522, 'name': 'ii_105522', 'unit_price': 112, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 141843, 'name': 'ii_141843', 'unit_price': 157, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 116083, 'name': 'ii_116083', 'unit_price': 162, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 102735, 'name': 'ii_102735', 'unit_price': 122, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 121777, 'name': 'ii_121777', 'unit_price': 125, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 107558, 'name': 'ii_107558', 'unit_price': 143, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 140426, 'name': 'ii_140426', 'unit_price': 109, 'type': 2},
#     'quantity': 2}]},
#  {'id': 385661,
#   'created_on': '2019-02-14',
#   'items': [{'item': {'id': 150660,
#      'name': 'ii_150660',
#      'unit_price': 107,
#      'type': 0},
#     'quantity': 5},
#    {'item': {'id': 197614, 'name': 'ii_197614', 'unit_price': 128, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 138654, 'name': 'ii_138654', 'unit_price': 147, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 192347, 'name': 'ii_192347', 'unit_price': 102, 'type': 0},
#     'quantity': 1}]},
#  {'id': 348894,
#   'created_on': '2019-07-14',
#   'items': [{'item': {'id': 159283,
#      'name': 'ii_159283',
#      'unit_price': 176,
#      'type': 3},
#     'quantity': -3},
#    {'item': {'id': 148220, 'name': 'ii_148220', 'unit_price': 149, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 109358, 'name': 'ii_109358', 'unit_price': 173, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 106227, 'name': 'ii_106227', 'unit_price': 197, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 135114, 'name': 'ii_135114', 'unit_price': 175, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 188146, 'name': 'ii_188146', 'unit_price': 184, 'type': 1},
#     'quantity': 1},
#    {'item': {'id': 149349, 'name': 'ii_149349', 'unit_price': 106, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 143455, 'name': 'ii_143455', 'unit_price': 131, 'type': 0},
#     'quantity': 5}]},
#  {'id': 378746,
#   'created_on': '2019-01-19',
#   'items': [{'item': {'id': 124023,
#      'name': 'ii_124023',
#      'unit_price': 161,
#      'type': 3},
#     'quantity': 4},
#    {'item': {'id': 153160, 'name': 'ii_153160', 'unit_price': 148, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 127600, 'name': 'ii_127600', 'unit_price': 114, 'type': 0},
#     'quantity': 5},
#    {'item': {'id': 166823, 'name': 'ii_166823', 'unit_price': 171, 'type': 0},
#     'quantity': 5},
#    {'item': {'id': 161026, 'name': 'ii_161026', 'unit_price': 197, 'type': 0},
#     'quantity': 8}]},
#  {'id': 374733,
#   'created_on': '2019-07-10',
#   'items': [{'item': {'id': 189737,
#      'name': 'ii_189737',
#      'unit_price': 158,
#      'type': 0},
#     'quantity': 1},
#    {'item': {'id': 136516, 'name': 'ii_136516', 'unit_price': 113, 'type': 0},
#     'quantity': 7},
#    {'item': {'id': 150673, 'name': 'ii_150673', 'unit_price': 114, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 163186, 'name': 'ii_163186', 'unit_price': 149, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 121879, 'name': 'ii_121879', 'unit_price': 153, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 101649, 'name': 'ii_101649', 'unit_price': 126, 'type': 3},
#     'quantity': 6}]},
#  {'id': 301695,
#   'created_on': '2019-04-26',
#   'items': [{'item': {'id': 166227,
#      'name': 'ii_166227',
#      'unit_price': 118,
#      'type': 1},
#     'quantity': 6},
#    {'item': {'id': 195625, 'name': 'ii_195625', 'unit_price': 148, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 103215, 'name': 'ii_103215', 'unit_price': 135, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 171394, 'name': 'ii_171394', 'unit_price': 128, 'type': 3},
#     'quantity': 1}]},
#  {'id': 351096,
#   'created_on': '2019-03-13',
#   'items': [{'item': {'id': 180576,
#      'name': 'ii_180576',
#      'unit_price': 144,
#      'type': 2},
#     'quantity': 3},
#    {'item': {'id': 191572, 'name': 'ii_191572', 'unit_price': 151, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 163806, 'name': 'ii_163806', 'unit_price': 172, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 121485, 'name': 'ii_121485', 'unit_price': 158, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 108171, 'name': 'ii_108171', 'unit_price': 148, 'type': 0},
#     'quantity': 5},
#    {'item': {'id': 157907, 'name': 'ii_157907', 'unit_price': 132, 'type': 3},
#     'quantity': 6}]},
#  {'id': 308939,
#   'created_on': '2019-05-18',
#   'items': [{'item': {'id': 138755,
#      'name': 'ii_138755',
#      'unit_price': 142,
#      'type': 0},
#     'quantity': 6},
#    {'item': {'id': 118810, 'name': 'ii_118810', 'unit_price': 178, 'type': 2},
#     'quantity': 8},
#    {'item': {'id': 147011, 'name': 'ii_147011', 'unit_price': 196, 'type': 3},
#     'quantity': 5}]},
#  {'id': 379387,
#   'created_on': '2019-06-22',
#   'items': [{'item': {'id': 198340,
#      'name': 'ii_198340',
#      'unit_price': 177,
#      'type': 3},
#     'quantity': 2},
#    {'item': {'id': 190876, 'name': 'ii_190876', 'unit_price': 104, 'type': 0},
#     'quantity': 2},
#    {'item': {'id': 175510, 'name': 'ii_175510', 'unit_price': 132, 'type': 0},
#     'quantity': 7}]},
#  {'id': '371786O',
#   'created_on': '2019-02-10',
#   'items': [{'item': {'id': 151075,
#      'name': 'ii_151075',
#      'unit_price': 134,
#      'type': 2},
#     'quantity': 5},
#    {'item': {'id': 132552, 'name': 'ii_132552', 'unit_price': 164, 'type': 1},
#     'quantity': 1}]},
#  {'id': 356532,
#   'created_on': '2019-01-14',
#   'items': [{'item': {'id': 157298,
#      'name': 'ii_157298',
#      'unit_price': 196,
#      'type': 1},
#     'quantity': 4},
#    {'item': {'id': 166980, 'name': 'ii_166980', 'unit_price': 172, 'type': 2},
#     'quantity': 7},
#    {'item': {'id': 123170, 'name': 'ii_123170', 'unit_price': 121, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 172501, 'name': 'ii_172501', 'unit_price': 161, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 125803, 'name': 'ii_125803', 'unit_price': 156, 'type': 0},
#     'quantity': 3}]},
#  {'id': '331902O',
#   'created_on': '2019-09-16',
#   'items': [{'item': {'id': 158537,
#      'name': 'ii_158537',
#      'unit_price': 197,
#      'type': 3},
#     'quantity': 6},
#    {'item': {'id': 154561, 'name': 'ii_154561', 'unit_price': 144, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 143905, 'name': 'ii_143905', 'unit_price': 179, 'type': 2},
#     'quantity': 4},
#    {'item': {'id': 198243, 'name': 'ii_198243', 'unit_price': 115, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 170438, 'name': 'ii_170438', 'unit_price': 183, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 111906, 'name': 'ii_111906', 'unit_price': 172, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 174442, 'name': 'ii_174442', 'unit_price': 131, 'type': 1},
#     'quantity': 2}]},
#  {'id': 328581,
#   'created_on': '2019-02-28',
#   'items': [{'item': {'id': 134847,
#      'name': 'ii_134847',
#      'unit_price': 191,
#      'type': 3},
#     'quantity': 2},
#    {'item': {'id': 130674, 'name': 'ii_130674', 'unit_price': 160, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 115532, 'name': 'ii_115532', 'unit_price': 194, 'type': 3},
#     'quantity': 7},
#    {'item': {'id': 176102, 'name': 'ii_176102', 'unit_price': 143, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 104028, 'name': 'ii_104028', 'unit_price': 148, 'type': 0},
#     'quantity': 7}]},
#  {'id': 325063,
#   'created_on': '2019-01-23',
#   'items': [{'item': {'id': 168501,
#      'name': 'ii_168501',
#      'unit_price': 130,
#      'type': 3},
#     'quantity': 5},
#    {'item': {'id': 129180, 'name': 'ii_129180', 'unit_price': 164, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 190265, 'name': 'ii_190265', 'unit_price': 164, 'type': 1},
#     'quantity': 4}]},
#  {'id': 375121,
#   'created_on': '2019-06-11',
#   'items': [{'item': {'id': 199708,
#      'name': 'ii_199708',
#      'unit_price': 116,
#      'type': 2},
#     'quantity': 5},
#    {'item': {'id': 147401, 'name': 'ii_147401', 'unit_price': 188, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 186192, 'name': 'ii_186192', 'unit_price': 163, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 191033, 'name': 'ii_191033', 'unit_price': 141, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 103236, 'name': 'ii_103236', 'unit_price': 148, 'type': 2},
#     'quantity': 6}]},
#  {'id': 368913,
#   'created_on': '2019-02-13',
#   'items': [{'item': {'id': 185615,
#      'name': 'ii_185615',
#      'unit_price': 143,
#      'type': 1},
#     'quantity': 5},
#    {'item': {'id': 110871, 'name': 'ii_110871', 'unit_price': 165, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 155308, 'name': 'ii_155308', 'unit_price': 185, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 194021, 'name': 'ii_194021', 'unit_price': 138, 'type': 1},
#     'quantity': 1},
#    {'item': {'id': 116641, 'name': 'ii_116641', 'unit_price': 172, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 199144, 'name': 'ii_199144', 'unit_price': 158, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 131362, 'name': 'ii_131362', 'unit_price': 131, 'type': 0},
#     'quantity': 3}]},
#  {'id': 383182,
#   'created_on': '2019-01-10',
#   'items': [{'item': {'id': 148618,
#      'name': 'ii_148618',
#      'unit_price': 124,
#      'type': 2},
#     'quantity': -1},
#    {'item': {'id': 144538, 'name': 'ii_144538', 'unit_price': 104, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 162678, 'name': 'ii_162678', 'unit_price': 120, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 102066, 'name': 'ii_102066', 'unit_price': 161, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 147577, 'name': 'ii_147577', 'unit_price': 167, 'type': 0},
#     'quantity': 1}]},
#  {'id': '308237O',
#   'created_on': '2019-05-29',
#   'items': [{'item': {'id': 157553,
#      'name': 'ii_157553',
#      'unit_price': 179,
#      'type': 3},
#     'quantity': 3},
#    {'item': {'id': 186670, 'name': 'ii_186670', 'unit_price': 181, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 140995, 'name': 'ii_140995', 'unit_price': 121, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 124546, 'name': 'ii_124546', 'unit_price': 170, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 167536, 'name': 'ii_167536', 'unit_price': 198, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 148625, 'name': 'ii_148625', 'unit_price': 185, 'type': 0},
#     'quantity': 2},
#    {'item': {'id': 146118, 'name': 'ii_146118', 'unit_price': 154, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 196020, 'name': 'ii_196020', 'unit_price': 172, 'type': 0},
#     'quantity': 4}]},
#  {'id': 376944,
#   'created_on': '2019-05-15',
#   'items': [{'item': {'id': 171249,
#      'name': 'ii_171249',
#      'unit_price': 131,
#      'type': 3},
#     'quantity': 5},
#    {'item': {'id': 179904, 'name': 'ii_179904', 'unit_price': 166, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 198049, 'name': 'ii_198049', 'unit_price': 113, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 116146, 'name': 'ii_116146', 'unit_price': 182, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 159836, 'name': 'ii_159836', 'unit_price': 109, 'type': 1},
#     'quantity': 4},
#    {'item': {'id': 148549, 'name': 'ii_148549', 'unit_price': 168, 'type': 0},
#     'quantity': 2}]},
#  {'id': 378408,
#   'created_on': '2019-09-24',
#   'items': [{'item': {'id': 130442,
#      'name': 'ii_130442',
#      'unit_price': 121,
#      'type': 1},
#     'quantity': 1},
#    {'item': {'id': 161956, 'name': 'ii_161956', 'unit_price': 186, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 160219, 'name': 'ii_160219', 'unit_price': 126, 'type': 0},
#     'quantity': 5},
#    {'item': {'id': 162332, 'name': 'ii_162332', 'unit_price': 160, 'type': 0},
#     'quantity': 6}]},
#  {'id': 315942,
#   'created_on': '2019-08-10',
#   'items': [{'item': {'id': 188151,
#      'name': 'ii_188151',
#      'unit_price': 124,
#      'type': 0},
#     'quantity': 2},
#    {'item': {'id': 145808, 'name': 'ii_145808', 'unit_price': 156, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 122308, 'name': 'ii_122308', 'unit_price': 143, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 197156, 'name': 'ii_197156', 'unit_price': 175, 'type': 1},
#     'quantity': 2}]},
#  {'id': 383281,
#   'created_on': '2019-01-20',
#   'items': [{'item': {'id': 139924,
#      'name': 'ii_139924',
#      'unit_price': 187,
#      'type': 1},
#     'quantity': 5},
#    {'item': {'id': 149461, 'name': 'ii_149461', 'unit_price': 193, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 157303, 'name': 'ii_157303', 'unit_price': 139, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 142649, 'name': 'ii_142649', 'unit_price': 177, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 155864, 'name': 'ii_155864', 'unit_price': 114, 'type': 3},
#     'quantity': 7}]},
#  {'id': 363263,
#   'created_on': '2019-04-26',
#   'items': [{'item': {'id': 164876,
#      'name': 'ii_164876',
#      'unit_price': 125,
#      'type': 2},
#     'quantity': 2},
#    {'item': {'id': 126912, 'name': 'ii_126912', 'unit_price': 132, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 195874, 'name': 'ii_195874', 'unit_price': 123, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 108933, 'name': 'ii_108933', 'unit_price': 114, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 145057, 'name': 'ii_145057', 'unit_price': 135, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 121049, 'name': 'ii_121049', 'unit_price': 115, 'type': 1},
#     'quantity': 3}]},
#  {'id': 369103,
#   'created_on': '2019-07-16',
#   'items': [{'item': {'id': 157581,
#      'name': 'ii_157581',
#      'unit_price': 134,
#      'type': 0},
#     'quantity': 2},
#    {'item': {'id': 149586, 'name': 'ii_149586', 'unit_price': 110, 'type': 0},
#     'quantity': 5}]},
#  {'id': 383235,
#   'created_on': '2019-01-15',
#   'items': [{'item': {'id': 149962,
#      'name': 'ii_149962',
#      'unit_price': 142,
#      'type': 2},
#     'quantity': 6},
#    {'item': {'id': 134235, 'name': 'ii_134235', 'unit_price': 173, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 122879, 'name': 'ii_122879', 'unit_price': 149, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 136748, 'name': 'ii_136748', 'unit_price': 186, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 177216, 'name': 'ii_177216', 'unit_price': 187, 'type': 2},
#     'quantity': 7}]},
#  {'id': 323231,
#   'created_on': '2019-07-19',
#   'items': [{'item': {'id': 143643,
#      'name': 'ii_143643',
#      'unit_price': 198,
#      'type': 1},
#     'quantity': 1},
#    {'item': {'id': 129005, 'name': 'ii_129005', 'unit_price': 132, 'type': 0},
#     'quantity': 4},
#    {'item': {'id': 198810, 'name': 'ii_198810', 'unit_price': 174, 'type': 0},
#     'quantity': 1}]},
#  {'id': '340299O',
#   'created_on': '2019-09-22',
#   'items': [{'item': {'id': 116922,
#      'name': 'ii_116922',
#      'unit_price': 121,
#      'type': 0},
#     'quantity': 8},
#    {'item': {'id': 104400, 'name': 'ii_104400', 'unit_price': 188, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 106905, 'name': 'ii_106905', 'unit_price': 108, 'type': 1},
#     'quantity': 5},
#    {'item': {'id': 128762, 'name': 'ii_128762', 'unit_price': 141, 'type': 3},
#     'quantity': 8}]},
#  {'id': 395841,
#   'created_on': '2019-01-13',
#   'items': [{'item': {'id': 127224,
#      'name': 'ii_127224',
#      'unit_price': 167,
#      'type': 3},
#     'quantity': 8},
#    {'item': {'id': 113035, 'name': 'ii_113035', 'unit_price': 103, 'type': 2},
#     'quantity': 7},
#    {'item': {'id': 101851, 'name': 'ii_101851', 'unit_price': 185, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 151324, 'name': 'ii_151324', 'unit_price': 119, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 197505, 'name': 'ii_197505', 'unit_price': 195, 'type': 3},
#     'quantity': 8},
#    {'item': {'id': 107412, 'name': 'ii_107412', 'unit_price': 126, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 176476, 'name': 'ii_176476', 'unit_price': 195, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 147134, 'name': 'ii_147134', 'unit_price': 170, 'type': 0},
#     'quantity': 1}]},
#  {'id': 391273,
#   'created_on': '2019-09-10',
#   'items': [{'item': {'id': 139726,
#      'name': 'ii_139726',
#      'unit_price': 161,
#      'type': 3},
#     'quantity': 1},
#    {'item': {'id': 169144, 'name': 'ii_169144', 'unit_price': 171, 'type': 1},
#     'quantity': 7},
#    {'item': {'id': 123472, 'name': 'ii_123472', 'unit_price': 192, 'type': 3},
#     'quantity': 1},
#    {'item': {'id': 196693, 'name': 'ii_196693', 'unit_price': 191, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 137187, 'name': 'ii_137187', 'unit_price': 151, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 188652, 'name': 'ii_188652', 'unit_price': 132, 'type': 0},
#     'quantity': 5},
#    {'item': {'id': 158194, 'name': 'ii_158194', 'unit_price': 188, 'type': 0},
#     'quantity': 4},
#    {'item': {'id': 193264, 'name': 'ii_193264', 'unit_price': 192, 'type': 0},
#     'quantity': 6}]},
#  {'id': 366751,
#   'created_on': '2019-02-30',
#   'items': [{'item': {'id': 175333,
#      'name': 'ii_175333',
#      'unit_price': 192,
#      'type': 3},
#     'quantity': 5},
#    {'item': {'id': 106160, 'name': 'ii_106160', 'unit_price': 107, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 160248, 'name': 'ii_160248', 'unit_price': 118, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 159445, 'name': 'ii_159445', 'unit_price': 144, 'type': 1},
#     'quantity': 5}]},
#  {'id': 313012,
#   'created_on': '2019-08-27',
#   'items': [{'item': {'id': 101173,
#      'name': 'ii_101173',
#      'unit_price': 117,
#      'type': 3},
#     'quantity': 'five'},
#    {'item': {'id': 195549, 'name': 'ii_195549', 'unit_price': 119, 'type': 0},
#     'quantity': 5}]},
#  {'id': 311671,
#   'created_on': '2019-05-30',
#   'items': [{'item': {'id': 162139,
#      'name': 'ii_162139',
#      'unit_price': 115,
#      'type': 3},
#     'quantity': 'ten'},
#    {'item': {'id': 124880, 'name': 'ii_124880', 'unit_price': 115, 'type': 0},
#     'quantity': 2},
#    {'item': {'id': 167564, 'name': 'ii_167564', 'unit_price': 155, 'type': 1},
#     'quantity': 4},
#    {'item': {'id': 184702, 'name': 'ii_184702', 'unit_price': 165, 'type': 3},
#     'quantity': 4},
#    {'item': {'id': 112399, 'name': 'ii_112399', 'unit_price': 121, 'type': 0},
#     'quantity': 8},
#    {'item': {'id': 142190, 'name': 'ii_142190', 'unit_price': 188, 'type': 0},
#     'quantity': 4}]},
#  {'id': 381457,
#   'created_on': '2019-07-13',
#   'items': [{'item': {'id': 151643,
#      'name': 'ii_151643',
#      'unit_price': 140,
#      'type': 1},
#     'quantity': 4},
#    {'item': {'id': 117135, 'name': 'ii_117135', 'unit_price': 150, 'type': 1},
#     'quantity': 4},
#    {'item': {'id': 191631, 'name': 'ii_191631', 'unit_price': 154, 'type': 2},
#     'quantity': 7},
#    {'item': {'id': 132707, 'name': 'ii_132707', 'unit_price': 132, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 166795, 'name': 'ii_166795', 'unit_price': 165, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 140959, 'name': 'ii_140959', 'unit_price': 177, 'type': 1},
#     'quantity': 6},
#    {'item': {'id': 186097, 'name': 'ii_186097', 'unit_price': 112, 'type': 0},
#     'quantity': 5}]},
#  {'id': 343254,
#   'created_on': '2019-07-12',
#   'items': [{'item': {'id': 104571,
#      'name': 'ii_104571',
#      'unit_price': 172,
#      'type': 3},
#     'quantity': 3},
#    {'item': {'id': 128915, 'name': 'ii_128915', 'unit_price': 109, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 177697, 'name': 'ii_177697', 'unit_price': 123, 'type': 1},
#     'quantity': 2},
#    {'item': {'id': 198244, 'name': 'ii_198244', 'unit_price': 119, 'type': 1},
#     'quantity': 1},
#    {'item': {'id': 134480, 'name': 'ii_134480', 'unit_price': 127, 'type': 0},
#     'quantity': 4},
#    {'item': {'id': 187069, 'name': 'ii_187069', 'unit_price': 111, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 163211, 'name': 'ii_163211', 'unit_price': 142, 'type': 3},
#     'quantity': 3},
#    {'item': {'id': 138776, 'name': 'ii_138776', 'unit_price': 189, 'type': 0},
#     'quantity': 6}]},
#  {'id': 330931,
#   'created_on': '2019-03-20',
#   'items': [{'item': {'id': 163035,
#      'name': 'ii_163035',
#      'unit_price': 123,
#      'type': 2},
#     'quantity': 8},
#    {'item': {'id': 182320, 'name': 'ii_182320', 'unit_price': 106, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 103864, 'name': 'ii_103864', 'unit_price': 148, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 185413, 'name': 'ii_185413', 'unit_price': 161, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 108965, 'name': 'ii_108965', 'unit_price': 138, 'type': 3},
#     'quantity': 3},
#    {'item': {'id': 175469, 'name': 'ii_175469', 'unit_price': 157, 'type': 3},
#     'quantity': 4}]},
#  {'id': 375592,
#   'created_on': '2019-02-30',
#   'items': [{'item': {'id': 157027,
#      'name': 'ii_157027',
#      'unit_price': 187,
#      'type': 1},
#     'quantity': -1},
#    {'item': {'id': 185821, 'name': 'ii_185821', 'unit_price': 157, 'type': 2},
#     'quantity': 3}]},
#  {'id': 386678,
#   'created_on': '2019-09-18',
#   'items': [{'item': {'id': 133300,
#      'name': 'ii_133300',
#      'unit_price': 130,
#      'type': 1},
#     'quantity': 7},
#    {'item': {'id': 124026, 'name': 'ii_124026', 'unit_price': 141, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 128660, 'name': 'ii_128660', 'unit_price': 196, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 143179, 'name': 'ii_143179', 'unit_price': 126, 'type': 1},
#     'quantity': 3}]},
#  {'id': 360664,
#   'created_on': '2019-06-26',
#   'items': [{'item': {'id': 180674,
#      'name': 'ii_180674',
#      'unit_price': 114,
#      'type': 3},
#     'quantity': 1},
#    {'item': {'id': 149216, 'name': 'ii_149216', 'unit_price': 192, 'type': 3},
#     'quantity': 2},
#    {'item': {'id': 156311, 'name': 'ii_156311', 'unit_price': 140, 'type': 1},
#     'quantity': 4},
#    {'item': {'id': 147252, 'name': 'ii_147252', 'unit_price': 166, 'type': 2},
#     'quantity': 6},
#    {'item': {'id': 112615, 'name': 'ii_112615', 'unit_price': 175, 'type': 1},
#     'quantity': 4},
#    {'item': {'id': 172997, 'name': 'ii_172997', 'unit_price': 171, 'type': 0},
#     'quantity': 1},
#    {'item': {'id': 133577, 'name': 'ii_133577', 'unit_price': 172, 'type': 2},
#     'quantity': 3}]},
#  {'id': 387341,
#   'created_on': '2019-01-27',
#   'items': [{'item': {'id': 104043,
#      'name': 'ii_104043',
#      'unit_price': 155,
#      'type': 0},
#     'quantity': 1},
#    {'item': {'id': 147191, 'name': 'ii_147191', 'unit_price': 109, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 178083, 'name': 'ii_178083', 'unit_price': 148, 'type': 0},
#     'quantity': 4},
#    {'item': {'id': 195056, 'name': 'ii_195056', 'unit_price': 177, 'type': 0},
#     'quantity': 8}]},
#  {'id': 305869,
#   'created_on': '2019-09-11',
#   'items': [{'item': {'id': 132142,
#      'name': 'ii_132142',
#      'unit_price': 101,
#      'type': 3},
#     'quantity': 'ten'},
#    {'item': {'id': 122089, 'name': 'ii_122089', 'unit_price': 126, 'type': 0},
#     'quantity': 2},
#    {'item': {'id': 167832, 'name': 'ii_167832', 'unit_price': 179, 'type': 0},
#     'quantity': 4},
#    {'item': {'id': 192367, 'name': 'ii_192367', 'unit_price': 156, 'type': 0},
#     'quantity': 3},
#    {'item': {'id': 121559, 'name': 'ii_121559', 'unit_price': 175, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 166763, 'name': 'ii_166763', 'unit_price': 155, 'type': 1},
#     'quantity': 8}]},
#  {'id': 356552,
#   'created_on': '2019-03-21',
#   'items': [{'item': {'id': 112495,
#      'name': 'ii_112495',
#      'unit_price': 104,
#      'type': 1},
#     'quantity': 4},
#    {'item': {'id': 196977, 'name': 'ii_196977', 'unit_price': 160, 'type': 1},
#     'quantity': 3},
#    {'item': {'id': 103631, 'name': 'ii_103631', 'unit_price': 133, 'type': 0},
#     'quantity': 6},
#    {'item': {'id': 185127, 'name': 'ii_185127', 'unit_price': 125, 'type': 0},
#     'quantity': 1}]},
#  {'id': 306163,
#   'created_on': '2019-09-18',
#   'items': [{'item': {'id': 136017,
#      'name': 'ii_136017',
#      'unit_price': 191,
#      'type': 1},
#     'quantity': 2},
#    {'item': {'id': 145491, 'name': 'ii_145491', 'unit_price': 114, 'type': 0},
#     'quantity': 2},
#    {'item': {'id': 167964, 'name': 'ii_167964', 'unit_price': 127, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 117418, 'name': 'ii_117418', 'unit_price': 122, 'type': 2},
#     'quantity': 1},
#    {'item': {'id': 137129, 'name': 'ii_137129', 'unit_price': 131, 'type': 2},
#     'quantity': 7},
#    {'item': {'id': 130442, 'name': 'ii_130442', 'unit_price': 160, 'type': 0},
#     'quantity': 2},
#    {'item': {'id': 108876, 'name': 'ii_108876', 'unit_price': 181, 'type': 0},
#     'quantity': 6}]},
#  {'id': '373375O',
#   'created_on': '2019-08-24',
#   'items': [{'item': {'id': 180383,
#      'name': 'ii_180383',
#      'unit_price': 179,
#      'type': 3},
#     'quantity': 8},
#    {'item': {'id': 129478, 'name': 'ii_129478', 'unit_price': 146, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 105522, 'name': 'ii_105522', 'unit_price': 154, 'type': 1},
#     'quantity': 8},
#    {'item': {'id': 141924, 'name': 'ii_141924', 'unit_price': 193, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 182015, 'name': 'ii_182015', 'unit_price': 149, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 159579, 'name': 'ii_159579', 'unit_price': 178, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 157738, 'name': 'ii_157738', 'unit_price': 130, 'type': 3},
#     'quantity': 5},
#    {'item': {'id': 139544, 'name': 'ii_139544', 'unit_price': 131, 'type': 3},
#     'quantity': 3}]},
#  {'id': 321243,
#   'created_on': '2019-05-26',
#   'items': [{'item': {'id': 124775,
#      'name': 'ii_124775',
#      'unit_price': 134,
#      'type': 3},
#     'quantity': 1},
#    {'item': {'id': 184165, 'name': 'ii_184165', 'unit_price': 175, 'type': 2},
#     'quantity': 5},
#    {'item': {'id': 155124, 'name': 'ii_155124', 'unit_price': 127, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 141626, 'name': 'ii_141626', 'unit_price': 144, 'type': 2},
#     'quantity': 2},
#    {'item': {'id': 175528, 'name': 'ii_175528', 'unit_price': 169, 'type': 1},
#     'quantity': 3}]},
#  {'id': 377960,
#   'created_on': '2019-02-22',
#   'items': [{'item': {'id': 123242,
#      'name': 'ii_123242',
#      'unit_price': 110,
#      'type': 1},
#     'quantity': 5},
#    {'item': {'id': 196386, 'name': 'ii_196386', 'unit_price': 150, 'type': 3},
#     'quantity': 6},
#    {'item': {'id': 196707, 'name': 'ii_196707', 'unit_price': 191, 'type': 2},
#     'quantity': 3},
#    {'item': {'id': 144902, 'name': 'ii_144902', 'unit_price': 188, 'type': 2},
#     'quantity': 7}]}]

# %% [markdown]
# **The DataExtractor class below implements functionalities that handle all the inconsistencies in the data, clean and process it, and transform it into a pandas Data Frame in the correct format.**

# %%
class DataExtractor:
    """
    Loads the existing data and transforms into the correct format.
    """
    
    def __init__(self):
        self.invoices, self.expired_invoices = self.load_data()
        self.data = self.transform_data(self.invoices, self.expired_invoices)
    
    def load_data(self):
        """
        Loads the new invoice data from the .pkl file and the expired invoide data from the .txt file.
        """

        with open("data\invoices_new.pkl", 'rb') as f:
            invoices = pickle.load(f)

        with open("data\expired_invoices.txt", 'r') as f:
            expired_invoices = set(map(int, f.read().split(', ')))
            
        return invoices, expired_invoices
    
    def clean_invoice_id(self, invoice_id):
        """
        Removes letters at the end of the invoice IDs.
        """
        return int(''.join(filter(str.isdigit, str(invoice_id))))
    
    def convert_quantity(self, quantity):
        """
        Converts the quantity to integers.
        """
        if isinstance(quantity, int):
            return quantity
        if quantity.isdigit():
            return int(quantity)
        
        quantity = quantity.lower()
        word_numbers = {
            'zero': 0, 'one': 1, 'two': 2, 'three': 3, 'four': 4,
            'five': 5, 'six': 6, 'seven': 7, 'eight': 8, 'nine': 9,
            'ten': 10} # example for up to ten numbers
        
        return word_numbers.get(quantity, 0)  # default to 0 if not found
    
    def convert_type(self, type_value):
        """
        Converts the type to a proper integer.
        """
        if type_value == 'O':
            return 0
        return int(type_value)
    
    def correct_date(self, date_str):
        """
        Handles the out-of-range date to the nearest valid date.
        """
        try:
            return pd.to_datetime(date_str)
        except ValueError:
            date_parts = date_str.split('-')
            year, month, day = map(int, date_parts)
            if month == 2 and day > 28:
                # Leap year
                if year % 4 == 0: #and (year % 100 != 0 or year % 400 == 0):
                    day = 29 
                else:
                    day = 28  # Non-leap year
            return pd.Timestamp(year=year, month=month, day=day)
    
    def transform_data(self, invoices, expired_invoices):
        """
        Transforms the data into the final format, creating a pandas Data Frame.
        """
        
        transformed_data = []
        
        type_conversion = {0: 'Material', 1: 'Equipment', 2: 'Service', 3: 'Other'} # to convert the type column
        
        for invoice in invoices:
            invoice_id = self.clean_invoice_id(invoice['id'])
            created_on = self.correct_date(invoice['created_on'])
            
            if 'items' not in invoice or not invoice['items']:
                continue # ensure that there is 'items' before proceeding
            invoice_total = sum(item['item']['unit_price'] * self.convert_quantity(item['quantity']) for item in invoice['items']) # later used in finding percentage
            
            is_expired = invoice_id in expired_invoices
        
            for item in invoice['items']:
                invoiceitem_id = int(item['item']['id'])
                invoiceitem_name = str(item['item']['name'])
                item_type_value = item['item']['type']
                item_type = str(type_conversion[self.convert_type(item_type_value)])
                unit_price = int(item['item']['unit_price'])
                quantity = self.convert_quantity(item['quantity'])
                total_price = unit_price * quantity
                percentage_in_invoice = float(total_price / invoice_total)

                transformed_data.append({
                    'invoice_id': invoice_id,
                    'created_on': created_on,
                    'invoiceitem_id': invoiceitem_id,
                    'invoiceitem_name': invoiceitem_name,
                    'type': item_type,
                    'unit_price': unit_price,
                    'total_price': total_price,
                    'percentage_in_invoice': percentage_in_invoice,
                    'is_expired': is_expired
                })
            
        data = pd.DataFrame(transformed_data)
        
        return data

# %%
extractor = DataExtractor()
df = extractor.data

# %%
df
# Out:
#      invoice_id created_on  invoiceitem_id invoiceitem_name       type  \
# 0        365371 2019-05-27          142446        ii_142446  Equipment
# 1        365371 2019-05-27          154019        ii_154019  Equipment
# 2        389528 2019-03-19          172535        ii_172535   Material
# 3        389528 2019-03-19          175208        ii_175208   Material
# 4        389528 2019-03-19          139970        ii_139970    Service
# ..          ...        ...             ...              ...        ...
# 487      321243 2019-05-26          175528        ii_175528  Equipment
# 488      377960 2019-02-22          123242        ii_123242  Equipment
# 489      377960 2019-02-22          196386        ii_196386      Other
# 490      377960 2019-02-22          196707        ii_196707    Service
# 491      377960 2019-02-22          144902        ii_144902    Service
#
#      unit_price  total_price  percentage_in_invoice  is_expired
# 0           182         1092               0.861199       False
# 1           176          176               0.138801       False
# 2           105          420               0.073311        True
# 3           109          763               0.133182        True
# 4           193          772               0.134753        True
# ..          ...          ...                    ...         ...
# 487         169          507               0.232037       False
# 488         110          550               0.164720        True
# 489         150          900               0.269542        True
# 490         191          573               0.171608        True
# 491         188         1316               0.394130        True
#
# [492 rows x 9 columns]

# %%
df.dtypes
# Out:
# invoice_id                        int64
# created_on               datetime64[ns]
# invoiceitem_id                    int64
# invoiceitem_name                 object
# type                             object
# unit_price                        int64
# total_price                       int64
# percentage_in_invoice           float64
# is_expired                         bool
# dtype: object

# %%
df.to_csv("DataFrame.csv")
